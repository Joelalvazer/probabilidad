# %% [markdown]
# <a href="https://colab.research.google.com/github/Joelalvazer/probabilidad/blob/main/Practica%203/Unidad%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#**probabilidad y estadistica**
## **unidad 1**
### docente: *Dr. Jose Gabriel Rodriguez Rivas*
#### Alumno: Joel Avalos Alvarez

# %% [markdown]
# #**probabilidad y estadistica**
# ## **unidad 1**
# ### docente: *Dr. Jose Gabriel Rodriguez Rivas*
# #### Alumno: Joel Avalos Alvarez
# ![image](https://github.com/JoseGabriel-ITD/ Probabilidad-y-Estadistica/blob/main/ Cintilla2004.png?raw=true)

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [96.3, 72.58, 92.87, 77.32, 68.25, 93.58, 68.39, 65.03, 64.11, 71.17, 67.24, 82.52, 75.22, 59.95, 55.03, 96.52, 88.95, 71.63, 77.62, 89.23, 77.07, 90.02, 79.58, 94.4, 98.91, 60.28, 54.53, 81.8, 86.54, 52.62, 98.43, 89.4, 89.03, 85.43, 67.28, 56.94, 93.38, 52.74, 54.78, 94.96, 96.0, 97.87, 57.74, 87.94, 58.15, 55.22, 54.41, 66.79, 90.33, 84.69, 98.17, 55.02, 84.15, 80.37, 55.04, 96.39, 83.07, 90.34, 96.74, 54.01, 54.41, 76.11, 85.83, 53.97, 69.0, 83.62, 57.88, 96.47, 65.37, 68.99, 80.28, 69.65, 98.54, 73.37, 69.6, 56.88, 65.47, 83.46, 97.9, 79.03, 94.02, 57.39, 96.21, 54.7, 66.92, 77.02, 77.97, 81.96, 79.91, 84.4, 75.47, 62.84, 54.14, 57.45, 72.56, 83.62, 77.88, 54.3, 72.38, 93.32]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [67.86, 81.61, 50.39, 62.93, 91.31, 54.9, 68.39, 44.09, 86.25, 40.98, 41.11, 73.46, 42.34, 49.31, 49.54, 63.21, 74.77, 62.08, 90.56, 75.63, 74.49, 70.06, 46.94, 53.04, 70.39, 82.9, 47.28, 75.6, 67.75, 57.19, 87.51, 41.77, 84.43, 87.76, 52.72, 61.44, 53.81, 89.46, 77.75, 71.17, 70.2, 40.48, 46.57, 68.07, 90.34, 88.95, 55.59, 79.38, 75.43, 48.93, 84.13, 43.78, 91.8, 56.62, 48.59, 63.78, 92.49, 71.26, 49.62, 76.93, 60.94, 48.09, 54.61, 63.76, 55.02, 87.84, 77.81, 62.09, 47.77, 92.03, 67.58, 55.18, 76.87, 87.86, 44.09, 41.94, 67.98, 88.04, 76.4, 51.2, 66.96, 63.93, 59.71, 72.08, 75.12, 85.99, 54.53, 69.05, 69.7, 47.36, 44.34, 76.22, 48.0, 88.08, 72.63, 62.38, 55.84, 75.79, 61.46, 92.29]

# %%
plt.boxplot(fabrica1)
plt.ylabel('Produccion en metros')
plt.title('Produccion de la fabrica 1')
plt.show()

# %%
plt.boxplot(fabrica2)
plt.ylabel('Produccion en metros')
plt.title('Produccion de la fabrica 2')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Produccion de la fabrica 1')
ax1.set_ylabel('Produccion fabrica 1')
bplot1 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Produccion de la fabrica 2')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('Produccion de la fabrica 1')
ax1.set_ylabel('Produccion fabrica 1')
bplot1 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('Produccion de la fabrica 2')
plt.show()
