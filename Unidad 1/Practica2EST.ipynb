# %% [markdown]
# <a href="https://colab.research.google.com/github/Joelalvazer/probabilidad/blob/main/Unidad%201/Practica2EST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#**probabilidad y estadistica**
## **unidad 1**
### docente: *Dr. Jose Gabriel Rodriguez Rivas*
#### Alumno: Joel Avalos Alvarez

import random
import matplotlib.pyplot as plt
from statistics import*

# %%
fabrica1 = []
for i in range (100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [95.72, 65.24, 92.42, 58.14, 84.34, 72.11, 82.42, 63.05, 75.82, 91.07, 72.71, 74.14, 92.04, 53.18, 51.53, 96.27, 93.9, 73.6, 88.97, 90.51, 68.01, 82.91, 81.2, 62.55, 96.01, 67.5, 69.62, 60.67, 88.29, 58.97, 99.02, 89.96, 69.96, 56.07, 56.44, 69.01, 56.42, 67.68, 67.9, 82.78, 76.74, 79.05, 70.97, 85.0, 75.61, 62.22, 54.83, 93.5, 70.31, 82.91, 74.2, 67.0, 66.8, 58.35, 87.46, 91.64, 55.54, 96.55, 85.55, 65.28, 82.56, 92.23, 96.64, 62.05, 71.53, 58.5, 50.91, 60.48, 99.91, 65.02, 53.32, 70.42, 76.14, 89.93, 53.53, 78.76, 53.87, 87.96, 95.85, 66.24, 56.15, 82.15, 63.69, 83.3, 97.97, 85.47, 76.89, 68.38, 90.75, 72.41, 97.81, 96.11, 81.58, 56.77, 53.48, 90.86, 89.87, 85.73, 53.64, 63.68]

# %%
fabrica2 = []
for i in range (100):
  numero_aleatorio2 = round(random.uniform(40, 93), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [91.46, 85.73, 60.29, 73.88, 64.79, 83.61, 69.67, 79.54, 85.95, 59.52, 44.6, 52.59, 55.11, 52.25, 66.34, 65.96, 67.03, 57.0, 65.69, 49.9, 43.5, 66.98, 56.54, 47.87, 79.36, 79.71, 78.19, 82.87, 75.28, 47.34, 91.27, 64.62, 73.64, 63.41, 90.71, 81.21, 80.68, 63.95, 71.3, 77.12, 87.2, 44.29, 78.47, 75.22, 44.83, 77.15, 57.49, 43.55, 66.52, 79.76, 82.35, 86.66, 80.43, 77.58, 77.16, 62.43, 55.8, 54.0, 44.86, 72.19, 56.17, 84.91, 68.46, 75.45, 82.78, 49.7, 61.49, 60.99, 80.51, 74.01, 72.95, 64.36, 51.37, 42.81, 48.41, 50.45, 45.73, 55.87, 57.87, 67.3, 49.85, 66.92, 74.32, 52.29, 84.93, 91.75, 79.1, 72.48, 58.41, 47.48, 73.77, 79.95, 66.61, 55.36, 65.96, 61.3, 55.28, 81.17, 71.01, 83.94]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("estadistica descriptiva de la fabrica 1 \n", "media =", media1, "\n", "mediana =", mediana1, "moda =", moda1, "\nmaximo =", maximo1, "minimo =", minimo1, "rango =", rango1)
# Out:
# estadistica descriptiva de la fabrica 1
#  media = 75.302
#  mediana = 74.17 moda = 82.91
# maximo = 99.91 minimo = 50.91 rango = 49.0

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("estadistica descriptiva de la fabrica 2 \n", "media =", media2, "\n", "mediana =", mediana2, "moda =", moda2, "\nmaximo =", maximo2, "minimo =", minimo2, "rango =", rango2)
# Out:
# estadistica descriptiva de la fabrica 2
#  media = 67.1787
#  mediana = 66.95 moda = 65.96
# maximo = 91.75 minimo = 42.81 rango = 48.94

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
plt.figure(figsize = (8, 6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color= 'b', linestyle ='dashed', linewidth=2, label=f'media={media1:.2f}')
plt.axvline(mediana1, color= 'r', linestyle ='dashed', linewidth=2, label=f'mediana={mediana1:.2f}')
plt.axvline(moda1, color= 'y', linestyle ='dashed', linewidth=2, label=f'moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle= 'dashed', linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle= 'dashed', linewidth=2)
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title('produccion diaria de la fabrica 1')
plt.legend()
plt.show()
# Out:
# 14.36029036593409

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
plt.figure(figsize = (8, 6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color= 'b', linestyle ='dashed', linewidth=2, label=f'media={media1:.2f}')
plt.axvline(mediana1, color= 'r', linestyle ='dashed', linewidth=2, label=f'mediana={mediana1:.2f}')
plt.axvline(moda1, color= 'y', linestyle ='dashed', linewidth=2, label=f'moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica2, color='black', linestyle= 'dashed', linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica2, color='black', linestyle= 'dashed', linewidth=2)
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title('produccion diaria de la fabrica 2')
plt.legend()
plt.show()
# Out:
# 13.597022449972291

# %%
import seaborn as sns

# la densidad grafica es una forma de visualizar la distribuicion de datos en
# un intervalo o periodo de tiempo continuo.
#se basa en un histograma que usa el suavizado de kernel para trazar valores,
# lo que permite obtener distribuiciones mas suaves al reducir el ruido.
#una curva de densidad muestra la ubicacion de la media y la mediana de una distribuicion.

sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
