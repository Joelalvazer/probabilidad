# %% [markdown]
# <a href="https://colab.research.google.com/github/Joelalvazer/probabilidad/blob/main/Unidad%201/Practica%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# **Probabilidad y estadística**

## Unidad 1

### Practica 3. Tabla de frecuencias y regla de sturges

### Facilitador: *Dr. José Gabriel Rodríguez Rivas*

### Alumno: Joel Avalos Alvarez

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacía que representa la edad de 100 personas
import random
edades = []
# Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable numero_aleatorio
    numero_aleatorio = random.randint(18, 70)
    # Agregamos el numero aleatorio a la lista de valores
    edades.append(numero_aleatorio)
print(edades)
# Out:
# [52, 26, 34, 19, 55, 51, 68, 26, 67, 24, 44, 37, 37, 57, 54, 19, 19, 60, 63, 20, 41, 29, 65, 69, 42, 29, 49, 23, 45, 41, 67, 53, 21, 27, 18, 44, 39, 55, 31, 25, 69, 61, 69, 48, 28, 68, 28, 37, 57, 63, 26, 32, 47, 41, 60, 58, 22, 51, 35, 54, 61, 52, 22, 40, 20, 21, 19, 35, 68, 63, 40, 56, 47, 46, 21, 46, 51, 70, 41, 35, 66, 62, 34, 40, 55, 46, 61, 26, 52, 34, 32, 32, 28, 66, 43, 22, 18, 34, 26, 41]

# %%
import pandas as pd

# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    52
# 1    26
# 2    34
# 3    19
# 4    55

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 26    18           2
# 2     19           4
# 27    20           2
# 10    21           3
# 8     22           3
# 34    23           1
# 29    24           1
# 40    25           1
# 0     26           5
# 32    27           1
# 18    28           3
# 22    29           2
# 30    31           1
# 9     32           3
# 3     34           4
# 15    35           3
# 7     37           3
# 31    39           1
# 16    40           3
# 1     41           5
# 36    42           1
# 45    43           1
# 19    44           2
# 35    45           1
# 14    46           3
# 25    47           2
# 41    48           1
# 37    49           1
# 13    51           3
# 5     52           3
# 33    53           1
# 21    54           2
# 4     55           3
# 42    56           1
# 24    57           2
# 39    58           1
# 23    60           2
# 17    61           3
# 44    62           1
# 12    63           3
# 38    65           1
# 28    66           2
# 20    67           2
# 6     68           3
# 11    69           3
# 43    70           1

# %%
tabla_frecuencias["Frecuencia Relativa"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa
# 26    18           2                 0.02
# 2     19           4                 0.04
# 27    20           2                 0.02
# 10    21           3                 0.03
# 8     22           3                 0.03
# 34    23           1                 0.01
# 29    24           1                 0.01
# 40    25           1                 0.01
# 0     26           5                 0.05
# 32    27           1                 0.01
# 18    28           3                 0.03
# 22    29           2                 0.02
# 30    31           1                 0.01
# 9     32           3                 0.03
# 3     34           4                 0.04
# 15    35           3                 0.03
# 7     37           3                 0.03
# 31    39           1                 0.01
# 16    40           3                 0.03
# 1     41           5                 0.05
# 36    42           1                 0.01
# 45    43           1                 0.01
# 19    44           2                 0.02
# 35    45           1                 0.01
# 14    46           3                 0.03
# 25    47           2                 0.02
# 41    48           1                 0.01
# 37    49           1                 0.01
# 13    51           3                 0.03
# 5     52           3                 0.03
# 33    53           1                 0.01
# 21    54           2                 0.02
# 4     55           3                 0.03
# 42    56           1                 0.01
# 24    57           2                 0.02
# 39    58           1                 0.01
# 23    60           2                 0.02
# 17    61           3                 0.03
# 44    62           1                 0.01
# 12    63           3                 0.03
# 38    65           1                 0.01
# 28    66           2                 0.02
# 20    67           2                 0.02
# 6     68           3                 0.03
# 11    69           3                 0.03
# 43    70           1                 0.01

# %%
tabla_frecuencias["Fre Porcentaje"] = tabla_frecuencias["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa  Fre Porcentaje
# 26    18           2                 0.02             2.0
# 2     19           4                 0.04             4.0
# 27    20           2                 0.02             2.0
# 10    21           3                 0.03             3.0
# 8     22           3                 0.03             3.0
# 34    23           1                 0.01             1.0
# 29    24           1                 0.01             1.0
# 40    25           1                 0.01             1.0
# 0     26           5                 0.05             5.0
# 32    27           1                 0.01             1.0
# 18    28           3                 0.03             3.0
# 22    29           2                 0.02             2.0
# 30    31           1                 0.01             1.0
# 9     32           3                 0.03             3.0
# 3     34           4                 0.04             4.0
# 15    35           3                 0.03             3.0
# 7     37           3                 0.03             3.0
# 31    39           1                 0.01             1.0
# 16    40           3                 0.03             3.0
# 1     41           5                 0.05             5.0
# 36    42           1                 0.01             1.0
# 45    43           1                 0.01             1.0
# 19    44           2                 0.02             2.0
# 35    45           1                 0.01             1.0
# 14    46           3                 0.03             3.0
# 25    47           2                 0.02             2.0
# 41    48           1                 0.01             1.0
# 37    49           1                 0.01             1.0
# 13    51           3                 0.03             3.0
# 5     52           3                 0.03             3.0
# 33    53           1                 0.01             1.0
# 21    54           2                 0.02             2.0
# 4     55           3                 0.03             3.0
# 42    56           1                 0.01             1.0
# 24    57           2                 0.02             2.0
# 39    58           1                 0.01             1.0
# 23    60           2                 0.02             2.0
# 17    61           3                 0.03             3.0
# 44    62           1                 0.01             1.0
# 12    63           3                 0.03             3.0
# 38    65           1                 0.01             1.0
# 28    66           2                 0.02             2.0
# 20    67           2                 0.02             2.0
# 6     68           3                 0.03             3.0
# 11    69           3                 0.03             3.0
# 43    70           1                 0.01             1.0

# %%
tabla_frecuencias["Frecuencia Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()

# %%
# Importamos la librería math de funciones matemáticas
import math
# Volvemos a usar la lista edades
print(edades)
# Out:
# [52, 26, 34, 19, 55, 51, 68, 26, 67, 24, 44, 37, 37, 57, 54, 19, 19, 60, 63, 20, 41, 29, 65, 69, 42, 29, 49, 23, 45, 41, 67, 53, 21, 27, 18, 44, 39, 55, 31, 25, 69, 61, 69, 48, 28, 68, 28, 37, 57, 63, 26, 32, 47, 41, 60, 58, 22, 51, 35, 54, 61, 52, 22, 40, 20, 21, 19, 35, 68, 63, 40, 56, 47, 46, 21, 46, 51, 70, 41, 35, 66, 62, 34, 40, 55, 46, 61, 26, 52, 34, 32, 32, 28, 66, 43, 22, 18, 34, 26, 41]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     52
# 1     26
# 2     34
# 3     19
# 4     55
# ..   ...
# 95    22
# 96    18
# 97    34
# 98    26
# 99    41
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
K = int(1 + math.log2(n))

print("Valor de n = ", n, "\nNúmero de intervalos = ", K)
# Crear la tabla de frecuencia
# Out:
# Valor de n =  100
# Número de intervalos =  7

# %%
 #Crear la tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    17
# 1  (25.429, 32.857]    15
# 2  (40.286, 47.714]    15
# 3    (62.571, 70.0]    15
# 4  (32.857, 40.286]    14
# 5  (47.714, 55.143]    14
# 6  (55.143, 62.571]    10

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    17
# 1  (25.429, 32.857]    15
# 4  (32.857, 40.286]    14
# 2  (40.286, 47.714]    15
# 5  (47.714, 55.143]    14
# 6  (55.143, 62.571]    10
# 3    (62.571, 70.0]    15

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Rel Ac  Frec Porc Ac
# 0  (17.947, 25.429]    17      0.17       17.0         0.17          17.0
# 1  (25.429, 32.857]    15      0.15       15.0         0.32          32.0
# 4  (32.857, 40.286]    14      0.14       14.0         0.46          46.0
# 2  (40.286, 47.714]    15      0.15       15.0         0.61          61.0
# 5  (47.714, 55.143]    14      0.14       14.0         0.75          75.0
# 6  (55.143, 62.571]    10      0.10       10.0         0.85          85.0
# 3    (62.571, 70.0]    15      0.15       15.0         1.00         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la función de matplotlib con valores estándar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estándar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
