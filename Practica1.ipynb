# %% [markdown]
# <a href="https://colab.research.google.com/github/Joelalvazer/probabilidad/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#**probabilidad y estadistica**
##grupo 2 y
## unidad 1

###Docente: Jose Gabriel Rodriguez Rivas
###Alumno: Joel Avalos Alvarez
###**practica1 medidas de tendencia central a histogramas**



from statistics import *

#Lista de calificaciones del grupo a
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)

type(grupoa)

promedio= sum(grupoa)/len(grupoa)
print(promedio)

promedio2=mean(grupoa)
print(promedio2)

mediana=median(grupoa)
print(mediana)

moda=mode(grupoa)
print(moda)

moda2=multimode(grupoa)
print(moda2)

tiempos100mts=[15.10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos100mts)

print("El tiempo promedio de los corredores es=> ", mean (tiempos100mts))

mediana=median(tiempos100mts)
print("La media  de los tiempos de los corredores es=> ", mediana)

moda=mode(tiempos100mts)
print("La moda de los tiempos es=>",moda)

multimoda=multimode(tiempos100mts)
print("La multi moda de los tiempos es=>",multimoda)

import random

fabrica1=[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2 )
  fabrica1.append(numero_aleatorio)
print(fabrica1)

fabrica2=[]
for i in range (100) :
  numero_aleatorio2 = round(random.uniform(40, 93), 2 )
  fabrica2.append(numero_aleatorio2)
print(fabrica2)

import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")

import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")

from statistics import *

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("La media de la fabrica 1 es=>",media1)
print("La mediana de la fabrica 1 es=>",mediana1)
print("La moda de la fabrica 1 es=>",moda1)

media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("La media de la fabrica 2 es=>",media2)
print("La mediana de la fabrica 2 es=>",mediana2)
print("La moda de la fabrica 2 es=>",moda2)

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 5))
ax1. hist(fabrica1)
ax2.hist(fabrica2)
plt. show()

plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label="Mediana")
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel ('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label="Mediana")
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel ('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70
# [70, 100]
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# El tiempo promedio de los corredores es=>  17.322
# La media  de los tiempos de los corredores es=>  17.2
# La moda de los tiempos es=> 15.1
# La multi moda de los tiempos es=> [15.1, 17.2]
# [65.43, 74.98, 50.54, 56.32, 97.46, 50.39, 53.77, 92.84, 86.09, 60.02, 90.72, 60.72, 88.64, 61.63, 66.77, 55.18, 63.94, 67.32, 83.07, 53.21, 71.67, 73.23, 67.89, 81.29, 75.24, 55.77, 60.72, 52.9, 89.78, 78.58, 63.89, 85.86, 52.79, 84.87, 54.7, 57.51, 71.21, 94.65, 73.96, 64.97, 59.0, 51.21, 93.41, 71.91, 94.54, 53.94, 60.85, 77.68, 91.1, 81.43, 95.66, 91.25, 83.04, 95.81, 58.64, 58.13, 64.57, 52.42, 75.49, 80.72, 86.38, 55.73, 56.37, 86.0, 61.0, 90.7, 88.49, 53.74, 99.16, 73.22, 95.62, 59.97, 97.58, 57.21, 98.23, 62.68, 51.81, 77.53, 76.63, 81.73, 71.57, 61.74, 99.7, 68.58, 78.58, 76.81, 72.98, 63.74, 67.41, 99.94, 80.16, 54.63, 85.95, 84.35, 81.33, 72.21, 66.68, 91.89, 85.78, 83.4]
# [75.21, 82.52, 67.09, 45.66, 89.18, 53.75, 85.61, 64.92, 69.48, 62.42, 55.98, 56.66, 66.76, 53.51, 42.51, 50.49, 60.42, 68.05, 51.04, 66.35, 57.43, 40.53, 67.27, 84.4, 52.56, 78.26, 64.45, 47.82, 63.18, 66.41, 61.0, 61.59, 48.32, 55.17, 62.18, 51.64, 51.55, 70.91, 89.58, 59.0, 57.82, 92.42, 89.71, 61.44, 50.08, 48.39, 50.91, 46.84, 51.57, 65.17, 80.23, 42.45, 72.92, 91.57, 77.65, 79.82, 40.54, 59.85, 43.88, 48.65, 77.0, 63.82, 92.51, 46.2, 55.11, 51.87, 64.52, 67.68, 58.73, 85.57, 79.63, 55.91, 74.45, 45.98, 59.8, 54.4, 51.21, 52.41, 43.36, 60.62, 88.45, 84.76, 82.74, 58.95, 61.57, 48.79, 83.85, 89.64, 73.5, 87.64, 75.65, 49.46, 41.74, 43.62, 69.48, 53.02, 58.96, 74.92, 80.87, 61.58]
# Valores de la fabrica 1
# La media de la fabrica 1 es=> 73.3853
# La mediana de la fabrica 1 es=> 73.1
# La moda de la fabrica 1 es=> 60.72
# Valores de la fabrica 2
# La media de la fabrica 2 es=> 63.6274
# La mediana de la fabrica 2 es=> 61.504999999999995
# La moda de la fabrica 2 es=> 69.48
